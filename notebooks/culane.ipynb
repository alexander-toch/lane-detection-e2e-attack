# %%
import numpy as np
np.set_printoptions(threshold=np.inf)
import cv2
import matplotlib.pyplot as plt

image = np.array(cv2.cvtColor(cv2.imread("culane_label.png"), cv2.COLOR_RGB2GRAY))

print(image.shape)

plt.imshow(image, 'gray',vmin=0,vmax=4)
# Out:
# (590, 1640)

# %%
image = np.array(cv2.cvtColor(cv2.imread("1_lanes.png"), cv2.COLOR_RGB2GRAY))

fig, ax = plt.subplots(figsize=(13, 6))
ax.imshow(image, 'gray', vmin=0, vmax=5)
ax.set_aspect('auto')
print(image.shape)
# Out:
# (720, 1280)

# %%
# image = np.array(cv2.imread("my_label.png", cv2.COLOR_RGB2GRAY))
image = np.array(cv2.imread("my_label.png", cv2.IMREAD_GRAYSCALE))
ret, thres = cv2.threshold(image, 128, 1, cv2.THRESH_BINARY)

# print(thres)

# plt.imshow(image,'gray',vmin=0,vmax=255)
plt.imshow(thres, 'gray',vmin=0,vmax=4)
